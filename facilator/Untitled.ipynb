# %%
import pandas as pd

# %%
design = pd.read_excel("Designs.xlsx")

# %%
design.head()
# Out:
#   Unnamed: 0                     Unnamed: 1         Unnamed: 2  \
# 0   Sr.\nNo.                           Name  Patent Agent\nNo.
# 1          1      Abhimanyu Kumar - Designs        D/1123/2009
# 2          2        Smita Chandra - Designs        D/2382/2013
# 3          3  R. Sakthiya Dakkshi - Designs               2533
# 4          4           Ajit Kumar   Designs       BR/1499/2011
#
#                                           Unnamed: 3  \
# 0  Postal Address” (as declared by\nthe facilitat...
# 1  B-29, 2nd Floor, Paryavaran\nComplex, New Delh...
# 2  Flat No. 1303, Tower 30, Lotus\nPanache, Secto...
# 3  Flat No. 6, Balaji Flats, No. 22,\nBalaji Stre...
# 4                      Glowwell, 201, Mohini Market,
#
#                                  Unnamed: 4     Unnamed: 5
# 0  Email (as provided by the\nfacilitators)          Phone
# 1              abhimanyu.kumar@algindia.com     9871944782
# 2               smita.chandra@algindian.com     9910072180
# ...

# %%
design
# Out:
#    Unnamed: 0                     Unnamed: 1         Unnamed: 2  \
# 0    Sr.\nNo.                           Name  Patent Agent\nNo.
# 1           1      Abhimanyu Kumar - Designs        D/1123/2009
# 2           2        Smita Chandra - Designs        D/2382/2013
# 3           3  R. Sakthiya Dakkshi - Designs               2533
# 4           4           Ajit Kumar   Designs       BR/1499/2011
# 5         NaN                            NaN                NaN
# 6           5     P. Sanjai Gandhi    Design       Enrl. No. Ms
# 7         NaN                            NaN           286/2000
# 8         NaN                            NaN                NaN
# 9           6            Ravi Mohla   Design         D/229/2016
# 10          7   Vedant Vijay Pujari - Design              13241
#
#                                            Unnamed: 3  \
# 0   Postal Address” (as declared by\nthe facilitat...
# 1   B-29, 2nd Floor, Paryavaran\nComplex, New Delh...
# ...

# %%
design.to_csv('Designs.csv')

# %%
designs = pd.read_csv("Designs.csv")

# %%
designs.drop(columns=["Index"], inplace=True)

# %%
designs.to_csv('Designs.csv')

# %%
designs
# Out:
#    Sr.No.                           Name Patent Agent No.  \
# 0     1.0      Abhimanyu Kumar - Designs      D/1123/2009
# 1     2.0        Smita Chandra - Designs      D/2382/2013
# 2     3.0  R. Sakthiya Dakkshi - Designs             2533
# 3     4.0           Ajit Kumar   Designs     BR/1499/2011
# 4     NaN                            NaN              NaN
# 5     5.0     P. Sanjai Gandhi    Design     Enrl. No. Ms
# 6     NaN                            NaN         286/2000
# 7     NaN                            NaN              NaN
# 8     6.0            Ravi Mohla   Design       D/229/2016
# 9     7.0   Vedant Vijay Pujari - Design            13241
#
#                                       Postal Address  \
# 0  B-29, 2nd Floor, Paryavaran\nComplex, New Delh...
# 1  Flat No. 1303, Tower 30, Lotus\nPanache, Secto...
# 2  Flat No. 6, Balaji Flats, No. 22,\nBalaji Stre...
# 3                      Glowwell, 201, Mohini Market,
# 4                    Exhibition Road, Patna   800001
# ...

# %%
designs.isnull().sum()
# Out:
# Sr.No.              3
# Name                3
# Patent Agent No.    2
# Postal Address      0
# Email               3
#  Phone              1
# dtype: int64

# %%
patent = pd.read_excel("Patents.xlsx")

# %%
patent.to_csv("Patents.csv")

# %%
patent = pd.read_csv("Patents.csv")

# %%
patent.drop(columns=['0'], inplace=True)

# %%
patent
# Out:
#     Sr. No.                        Name  Patent Agent No.  \
# 0       1.0            Abhishek Magotra            1517.0
# 1       2.0           Adv. Jinisha Shah            1853.0
# 2       3.0     Adv. Parag Manohar more            1688.0
# 3       4.0                 AFZAL HASAN            1328.0
# 4       5.0        Akhilesh Kumar Gupta            1303.0
# 5       6.0                  Anil Kumar            2181.0
# 6       7.0                   Anjan Sen             199.0
# 7       8.0  ANUGU VIJAYA BHASKAR REDDY            2420.0
# 8       9.0              Anuradha Gupta            1514.0
# 9      10.0                Ayush Sharma            1348.0
# 10     11.0               Bandita Panda            1880.0
# 11     12.0            Basavarajappa NT            2509.0
# 12     13.0                 Beena Kurup            2378.0
# 13     14.0             Bhuvaneshwari E            2240.0
# 14     15.0              BIRENDRA KUMAR            1102.0
# ...
